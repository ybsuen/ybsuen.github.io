# %% [markdown]
# <div style="padding-top:5px;background:black;color:white;"><h1><center>Quick Revision of Python List and Dictionary</center</h1></div>

# %% [markdown]
# <center><h2 style="color:#566573;">Process list elements inside a loop.</h2></center>

# %%
name_list = ['John',"Mike","Mary","Jane"]
hrs_list = [30.0,40.0,50.0,60.0]
rate_list = [65.0,75.0,65.0,75.0]
index  = 0
for number in name_list:
    print(number)
    hrs = hrs_list[index]
    rate = rate_list[index]
    fee = fee = hrs * rate
    money_made = name_list[index] + " makes $" + str(fee) + "."
    print(hrs,rate,fee, money_made)
    index = index + 1
# Out:
# John
# 30.0 65.0 1950.0 John makes $1950.0.
# Mike
# 40.0 75.0 3000.0 Mike makes $3000.0.
# Mary
# 50.0 65.0 3250.0 Mary makes $3250.0.
# Jane
# 60.0 75.0 4500.0 Jane makes $4500.0.

# %%
hrs_list = [30.0,40.0,50.0,60.0]
rate_list = [65.0,75.0,65.0,75.0]
name_list = ['John',"Mike","Mary","Jane"]
fee_list = []
for number in range(len(name_list)):
        print(number)
        hrs = hrs_list[number]
        rate = rate_list[number]
        fee = hrs * rate
        fee_list.append(fee)
        money_made = name_list[number] + " makes " + str(fee) + "."
        print(hrs,rate,fee, money_made)  
money_list = []
money_list.append(name_list)
money_list.append(fee_list)
print(money_list)
# Out:
# 0
# 30.0 65.0 1950.0 John makes 1950.0.
# 1
# 40.0 75.0 3000.0 Mike makes 3000.0.
# 2
# 50.0 65.0 3250.0 Mary makes 3250.0.
# 3
# 60.0 75.0 4500.0 Jane makes 4500.0.
# [['John', 'Mike', 'Mary', 'Jane'], [1950.0, 3000.0, 3250.0, 4500.0]]

# %% [markdown]
# <center><h2 style="color:#566573;">Input and process list elements inside a loop.</h2></center>

# %%
# Input first name and last name and print out full name
print('Enter your first name:')
fname = input()
print('Enter your last name:')
lname = input()
print('Hello, ' + fname + ' ' + lname + '.')
# Out:
# Enter your first name:
# Bernard
# Enter your last name:
# Suen
# Hello, Bernard Suen.

# %% [raw]
# Formula for converting Celcius into Fahrenheit: (23°C × 9/5) + 32 = 73.4°F
# Create a list of temperature in Fahrenheit for the week based on the temperature of Celcius as follows:
#
#     Sun  Mon  Tue  Wed  Thu  Fri  Sat
#     23°C 24°C  28°C 19°C 17°C  21°C 25°C

# %% [raw]
# For more flexible handling: Entering the temperature in Celcius through an input box inside a loop and print out each day's temperature and calculate the weekly average in Fahrenheit.

# %%
weekly_temp = []
total_temp = 0
week_of_day =['Sun','Mon','Tue','Wed','Thu','Fri','Sat']
for i in week_of_day:
    temp = input("Enter " + i + "'s temperature in celcius:")
    temp = (float(temp) * 9/5) + 32 
    weekly_temp.append(int(temp))
    print(i + "'s temperature in Fahrenheit:" + str(temp))
    total_temp = total_temp + float(temp)
avg_temp = round((total_temp/7),2)
print("Average temperature for the week:" + str(avg_temp))
# Out:
# Enter Sun's temperature in celcius:20
# Sun's temperature in Fahrenheit:68.0
# Enter Mon's temperature in celcius:21
# Mon's temperature in Fahrenheit:69.8
# Enter Tue's temperature in celcius:22
# Tue's temperature in Fahrenheit:71.6
# Enter Wed's temperature in celcius:23
# Wed's temperature in Fahrenheit:73.4
# Enter Thu's temperature in celcius:24
# Thu's temperature in Fahrenheit:75.2
# Enter Fri's temperature in celcius:25
# Fri's temperature in Fahrenheit:77.0
# Enter Sat's temperature in celcius:19
# Sat's temperature in Fahrenheit:66.2
# Average temperature for the week:71.6

# %% [markdown]
# <center><h2 style="color:#566573;">Process dictionary elements inside a loop.</h2></center>

# %%
# dictinarly as value pairs
dict = {'Peter':80,"David":90,"Mary":100}
print(dict)
print(dict.keys())
print(dict.values())
# accessing individualy element through its key
print(dict["David"])
# Out:
# {'Peter': 80, 'David': 90, 'Mary': 100}
# dict_keys(['Peter', 'David', 'Mary'])
# dict_values([80, 90, 100])
# 90

# %%
dict = {'Peter':80,"David":90,"Mary":100}
# print out key and value referenced by the key
for key in dict:
  print(key, dict[key])
# Out:
# Peter 80
# David 90
# Mary 100

# %% [markdown]
# <div style="padding-top:5px;background:black;color:white;"><h1><center>Creating Pandas Data Frames from Lists and Dictionaries</center></h1></div>

# %% [markdown]
# <center><h2 style="color:#566573;">Data Frames from list of Dictionaries and list of lists</h2></center>

# %%
import pandas as pd
# Define a list of dictionaries
scores = [{'assignment scores': 'David Chan', 'Jan': 90, 'Feb': 85, 'Mar': 88},
         {'assignment scores': 'Peter Lee',  'Jan': 72, 'Feb': 75, 'Mar': 68},
         {'assignment scores': 'John Lui',  'Jan': 60,  'Feb': 80,  'Mar': 100 }]
df = pd.DataFrame(scores) # Assign the list of dictionaries to a dataframe
df # display dataframe
# Out:
#   assignment scores  Jan  Feb  Mar
# 0        David Chan   90   85   88
# 1         Peter Lee   72   75   68
# 2          John Lui   60   80  100

# %%
import pandas as pd
# define dataframe as a list of lists
# with a header list called columns which contains the column names
df = pd.DataFrame([
  [1, 'David Chan', 'dchan@cuhk.edu.hk'],
  [2, 'Peter Lee', 'plee@cuhk.edu.hk'],
  [3,'John Lui','jlui@cuhk.edu.hk'],
  [4,'Mary Lu','mlu@cuhk.edu.hk']
],
  columns=[ 
  'Student ID','Full Name','Email Address'
  ])
df
# Out:
#    Student ID   Full Name      Email Address
# 0           1  David Chan  dchan@cuhk.edu.hk
# 1           2   Peter Lee   plee@cuhk.edu.hk
# 2           3    John Lui   jlui@cuhk.edu.hk
# 3           4     Mary Lu    mlu@cuhk.edu.hk

# %% [markdown]
# <center><h2 style="color:#566573;">Data Frames from Dictionary of Lists</h2></center>

# %%
# Define a dictionary of list
scores = {'assignment scores': ['David Chan', 'Peter Lee', 'John Lui'],
         'Jan': [90, 72, 60],
         'Feb': [85, 75, 80],
         'Mar': [88, 68, 100]}
df = pd.DataFrame.from_dict(scores) # Assign the dictionary of lists to a dataframe 
df # display dataframe
# Out:
#   assignment scores  Jan  Feb  Mar
# 0        David Chan   90   85   88
# 1         Peter Lee   72   75   68
# 2          John Lui   60   80  100

# %%
# Define a dictionary of list directily inside the data frame
import pandas as pd
df = pd.DataFrame({ # Define dataframe as a dictionary object
  'Student ID': [1111, 1112, 1113, 1114],
'Student Name': ['David Chan','Peter Lee','John Lui','Mary Lu'],
'Email Address':['dchan@cuhk.edu.hk','plee@cuhk.edu.hk','jlui@cuhk.edu.hk','mlu@cuhk.edu.hk']
})
df
# Out:
#    Student ID Student Name      Email Address
# 0        1111   David Chan  dchan@cuhk.edu.hk
# 1        1112    Peter Lee   plee@cuhk.edu.hk
# 2        1113     John Lui   jlui@cuhk.edu.hk
# 3        1114      Mary Lu    mlu@cuhk.edu.hk

# %% [markdown]
# <h1><center>Saving To and Retrieving From CSV Files </center></h1>

# %% [markdown]
# <center><h2 style="color:#566573;">Saving Pandas Data Frame To a CSV File</h2></center>

# %%
import pandas as pd
# Define a list of dictionaries
scores = [{'assignment scores': 'David Chan', 'Jan': 90, 'Feb': 85, 'Mar': 88},
         {'assignment scores': 'Peter Lee',  'Jan': 72, 'Feb': 75, 'Mar': 68},
         {'assignment scores': 'John Lui',  'Jan': 60,  'Feb': 80,  'Mar': 100 }]
df = pd.DataFrame(scores) # Assign the list of dictionaries to a dataframe
df # display dataframe
df.to_csv('students.csv',mode='w',index=False)
df

# %% [markdown]
# <center><h2 style="color:#566573;">Reading Data From a CSV File Into a Pandas Data Frame</h2></center>

# %%
import pandas as pd
df = pd.read_csv("students.csv") # import csv file by using the read_csv functon in Pandas
df # list the dataframe
# Out:
#   assignment scores  Jan  Feb  Mar
# 0        David Chan   90   85   88
# 1         Peter Lee   72   75   68
# 2          John Lui   60   80  100

# %% [markdown]
# <div style="padding-top:5px;background:black;color:white;"><h1><center>Scrap Single Page Table Using BeautifulSoup</center></h1></div>

# %% [markdown]
# ![list_of_countries.png](attachment:list_of_countries.png)

# %% [markdown]
# <h1><center>List of Countries and Dependencies by Population</center></h1>

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

# %% [markdown]
# ![population_table.png](attachment:population_table.png)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv

url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv

url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')
table = soup.find("table", attrs={"class": "wikitable"})
table_data = table.tbody.find_all("tr")  # contains all the rows
# Fetch table headers
headings = []
rows = []
for th in table_data[0].find_all("th"):
    # print(th.getText())
    # headings.append(th.getText())
    headings.append(th.getText().strip())
# Fetch table body
h0 = headings[0]
h1 = headings[1]
h2 = headings[2]
h3 = headings[3]
h4 = headings[4]
h5 = headings[5]
row_index = 1 # row index for controlling the loop through all rows
for tbody in table_data[1:len(table_data)]:
    row = tbody.find_all("td")
    col_index = 0 # column index for controlling the loop through all columns
    dict = {}
    dict[h0] = tbody.find("th").getText().strip()
    val = dict[h0]
    # print(row_index,col_index,val)
    for td in row:
        if col_index == 0:
            dict[h1] = td.getText().strip()
            val = dict[h1]
        if col_index == 1:
            dict[h2] = td.getText().strip()
            val = dict[h2]
        if col_index == 2:
            dict[h3] = td.getText().strip()
            val = dict[h3]
        if col_index == 3:
            dict[h4] = td.getText().strip() 
            val = dict[h4]
        if col_index == 4:
            dict[h5] = td.getText().strip()   
            val = dict[h5]
        # print(row_index,col_index+1,val)
        col_index = col_index + 1
    rows.append(dict)
    row_index = row_index + 1
# Define a list of dictionaries
df = pd.DataFrame(rows) # Assign the list of dictionaries to a dataframe
df # display dataframe
df.to_csv('population.csv',mode='w',index=False)
df
# Out:
#     Rank      Country(or dependent territory)     Population    % of world  \
# 0      1                             China[b]  1,405,239,080         18.0%
# 1      2                             India[c]  1,369,434,247         17.5%
# 2      3                     United States[d]    330,617,844         4.22%
# 3      4                            Indonesia    269,603,400         3.45%
# 4      5                          Pakistan[e]    220,892,331         2.82%
# ..   ...                                  ...            ...           ...
# 237    –                         Tokelau (NZ)          1,499    0.0000192%
# 238  195                     Vatican City[ab]            825    0.0000105%
# 239    –  Cocos (Keeling) Islands (Australia)            555   0.00000709%
# 240    –                Pitcairn Islands (UK)             50  0.000000639%
# 241                                       NaN            NaN           NaN
#
#             Date          Source(official or UN)
# ...

# %% [markdown]
# <h1><center>List of Nobel Laureates</center></h1>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv

url = "https://en.wikipedia.org/wiki/List_of_Nobel_laureates"
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')
table = soup.find("table", attrs={"class": "wikitable"})
table_data = table.tbody.find_all("tr")  # contains 1 row
# Fetch table headers
headings = []
rows = []
for th in table_data[0].find_all("th"):
    # print(th.getText())
    # headings.append(th.getText())
    headings.append(th.getText().strip())
# Fetch table body
h0 = headings[0]
h1 = headings[1]
h2 = headings[2]
h3 = headings[3]
h4 = headings[4]
h5 = headings[5]
h6 = headings[6]
row_index = 1 # row index for controlling the loop through all rows
for tbody in table_data[1:len(table_data)]:
    row = tbody.find_all("td")
    col_index = 0 # column index for controlling the loop through all columns
    dict = {}
    # dict[h0] = tbody.find("th").getText().strip()
    # val = dict[h0]
    # print(row_index,col_index,val)
    for td in row:
        if col_index == 0:
            dict[h0] = td.getText().strip()
            val = dict[h0]
        if col_index == 1:
            dict[h1] = td.getText().strip()
            val = dict[h1]
        if col_index == 2:
            dict[h2] = td.getText().strip()
            val = dict[h2]
        if col_index == 3:
            dict[h3] = td.getText().strip() 
            val = dict[h3]
        if col_index == 4:
            dict[h4] = td.getText().strip()   
            val = dict[h4]
        if col_index == 5:
            dict[h5] = td.getText().strip()   
            val = dict[h5]
        if col_index == 6:
            dict[h6] = td.getText().strip()   
            val = dict[h6]
        # print(row_index,col_index+1,val)
        col_index = col_index + 1
    rows.append(dict)
    row_index = row_index + 1
# Define a list of dictionaries
df = pd.DataFrame(rows) # Assign the list of dictionaries to a dataframe
df # display dataframe
df.to_csv('nobel_laureates.csv',mode='w',index=False)
df
# Out:
#      Year                                         Physics  \
# 0    1901                                 Wilhelm Röntgen
# 1    1902                   Hendrik Lorentz;Pieter Zeeman
# 2    1903        Henri Becquerel;Pierre Curie;Marie Curie
# 3    1904                                   Lord Rayleigh
# 4    1905                                  Philipp Lenard
# ..    ...                                             ...
# 116  2017            Rainer Weiss;Barry Barish;Kip Thorne
# 117  2018    Arthur Ashkin;Gérard Mourou;Donna Strickland
# 118  2019      James Peebles; Michel Mayor; Didier Queloz
# 119  2020  Roger Penrose; Reinhard Genzel; Andrea M. Ghez
# 120   NaN                                             NaN
#
#                                              Chemistry  \
# 0                         Jacobus Henricus van 't Hoff
# 1                                 Hermann Emil Fischer
# 2                                     Svante Arrhenius
# ...

# %% [markdown]
# <div style="padding-top:5px;background:black;color:white;"><h1><center>Scrap Multiple Pages Using BeautifulSoup</center></h1></div>

# %% [markdown]
# <h1><center>eshop.cataloghk.com(<a href='https://eshop.cataloghk.com/footwear.html' target='_blank'>https://eshop.cataloghk.com/footwear.html)</a></h1>

# %%
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup

header = ['page #','brand','url','product','price']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
    quote_page = requests.get('https://eshop.cataloghk.com/footwear.html?p='+str(i)) 
    # print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(quote_page.content,'html.parser')
    for item in soup.find_all("li", attrs={"class":"item product product-item"}):
         page_no = str(i)
         brand = item.find("div",attrs={"class":"product details product-item-details box-info"}).span.get_text()
         url = item.find("div",attrs={"class":"product details product-item-details box-info"}).a.get('href')
         product = item.find("a",attrs={"class":"product-item-link"}).get_text().strip()
         price = item.find("span",attrs={"class":"price"}).get_text().strip()
         # print(brand)
         # print(url)
         # print(product)
         # print(price)
         data.append((page_no, brand, url, product, price))
        
df = pd.DataFrame(data,
   columns = header
)
df.to_csv('eshop_catalog.csv', sep='\t', encoding='utf-8')
df
# Out:
#     page #          brand                                               url  \
# 0        1          VANS    https://eshop.cataloghk.com/105vn0a2rr11ve.html
# 1        1   New Balance        https://eshop.cataloghk.com/112ws327kc.html
# 2        1          VANS    https://eshop.cataloghk.com/105vn0a2rr11v2.html
# 3        1        Reebok         https://eshop.cataloghk.com/101fv2392.html
# 4        1      Converse        https://eshop.cataloghk.com/150569433c.html
# ..     ...            ...                                               ...
# 175      3   New Balance       https://eshop.cataloghk.com/112ws327coc.html
# 176      3   New Balance       https://eshop.cataloghk.com/112ms327sfa.html
# 177      3        Reebok         https://eshop.cataloghk.com/101fv2395.html
# 178      3          Teva   https://eshop.cataloghk.com/1661116376brnbw.html
# 179      3          Teva    https://eshop.cataloghk.com/1661004006rwbc.html
#
#                                    product      price
# ...

# %% [markdown]
# <h1><center>Scraping Hong Kong Economic Journal - Fintech Stories
#     (<a href='http://startupbeat.hkej.com/?tag=fintech&paged=1' target='_blank'>http://startupbeat.hkej.com</a>)

# %%
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup

header = ['page #','title','url','details','post date']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
    quote_page = requests.get('http://startupbeat.hkej.com/?tag=fintech&paged='+str(i)) 
    print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(quote_page.content,'html.parser')
    
    for article in soup.find_all("div", attrs={"class":"archive-text"}):
    # for article in soup.find_all('div',class_='archive-text'):
         page_no = str(i)
         title = article.a.get_text()
         url = article.a.get('href')
         details = article.p.get_text()
         post_date = article.div.ul.li.text
         print(title)
         print(url)
         print(details)
         print(post_date)
         data.append((page_no, title, url, details, post_date))
        
df = pd.DataFrame(data,
  columns = header
)
df.to_csv('startup_beat_data_1.csv', sep='\t', encoding='utf-8')
df
# Out:
# ***** Page 1 in action *****
# 保險科企Coherent融資逾億
# http://startupbeat.hkej.com/?p=95034
# 本地保險科技（InsurTech）初創企業Coherent昨宣布，獲得A輪融資1400萬美元（約1.09億港元），資金由跨境風險投資基金凱輝創新基金及富蘭克林鄧普頓提供。
# Posted November 11, 2020
# HKbitEX：7號金融牌申領門檻高
# http://startupbeat.hkej.com/?p=94950
# HKbitEX剛完成約1000萬美元A2輪融資，估值達5000萬美元。至於公司業務，盧廷匡指會以「法幣」（虛擬資產與法定貨幣的交易）和STO（證券代幣發行）為主。
# Posted November 9, 2020
# 港支付商天使輪籌3900萬 Statrys冀擴大中小企滙款服務
# http://startupbeat.hkej.com/?p=94690
# 數碼支付服務公司Statrys近期完成一筆500萬美元（約3900萬港元）的天使輪投資，新資金有助公司加速開發及推出新產品，在數碼支付及滙款領域持續擴張。
# Posted November 3, 2020
# 破除數據決策盲點 (車品覺)
# http://startupbeat.hkej.com/?p=94669
# 數據驅動過程極需要業務方的支持與諒解，此時老闆的行為態度起了很大作用，例如Lucy喜歡把產品體驗排行榜放在辦公室門口，讓做得不好的產品總監「遊街」示眾。
# Posted November 2, 2020
# 洗廁所都有過億身家 (高天佑)
# http://startupbeat.hkej.com/?p=94516
# 誰都知道最好在創辦第一年，就投身阿里、騰訊（00700）、 Facebook或Tesla，不難憑options賺到過億元身家。惟這回事要講命水，畢竟超過八成startup執笠收場，股權價值歸零。
# Posted October 29, 2020
# 電子貨幣利與弊 (方保僑)
# http://startupbeat.hkej.com/?p=94367
# ...

# %% [markdown]
# <h1><center>Scraping Hong Kong Economic Journal - Covid Stories
#     (<a href='https://www1.hkej.com/features/topic/tag/%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95?&page=1' target='_blank'>http://startupbeat.hkej.com</a>)

# %%
# quote_page = requests.get('https://www1.hkej.com/features/topic/tag/%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95?&paged=1') 
# soup = BeautifulSoup(quote_page.text,'html.parser')
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup

header = ['page #','title','url','details','post date']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
    quote_page = requests.get('https://www1.hkej.com/features/topic/tag/%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95?&page='+str(i)) 
    print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(quote_page.content,'html.parser')
    
    for article in soup.find_all("li", attrs={"class":"fea_list_n"}):
         page_no = str(i)
         title = article.find("div",attrs={"class":"fea_list_n_topic"}).get_text()
         url = article.a.get('href')
         details = article.find("div",attrs={"class":"fea_list_n_sub fea_list_n_recap"}).a.get_text()
         post_date = article.find("div",attrs={"class":"fea_list_n_sub"}).get_text()
         post_date = post_date[-13:].strip()
         print(title)
         print(url)
         print(details)
         print(post_date)
         data.append((page_no, title, url, details, post_date))
        
df = pd.DataFrame(data,
  columns = header
)
df.to_csv('startup_beat_data_2.csv', sep='\t', encoding='utf-8')
df
# Out:
# ***** Page 1 in action *****
# 歐英訂購3.4億劑輝瑞新冠疫苗
# http://www1.hkej.com/features/article?q=%23%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95%23&suid=2846882716
# 美國藥廠輝瑞(Pfizer)和德國藥廠BioNTech合作的新冠疫苗，在預防染疫方面有效程度超過九成。歐盟及英 ...
# 2020年11月10日
# 南韓單日增百宗確診 71宗社區感染
# http://www1.hkej.com/features/article?q=%23%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95%23&suid=575498517
# 南韓中央防疫對策本部稱，當地新增100宗確診感染新型冠狀病毒肺炎病例，累計確診27653宗。另外，當地新增5宗 ...
# 2020年11月10日
# 巴西暫停中國科興新冠病毒疫苗臨床試驗
# http://www1.hkej.com/features/article?q=%23%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95%23&suid=2384436788
# 巴西聯邦衞生監管機構Anvisa表示，已暫停中國科興新冠病毒疫苗的臨床試驗，因10月29日發生嚴重不良反應。
#  ...
# 2020年11月10日
# 福西料美國年底前開始分配新冠疫苗
# http://www1.hkej.com/features/article?q=%23%E7%98%9F%E7%96%AB%E5%A4%A7%E6%B5%81%E8%A1%8C%E6%9C%80%E6%96%B0%E7%99%BC%E5%B1%95%23&suid=2327106261
# 美國藥廠輝瑞(Pfizer)和德國藥廠BioNTech合作的新冠疫苗，在預防染疫方面有效程度超過九成。白宮首席 ...
# 2020年11月10日
# ...

# %% [markdown]
# <div style="padding-top:5px;background:black;color:white;"><h1><center>Scrap and Chart</center></h1></div>

# %% [markdown]
# <h1><center>Understanding the Python Enumerate Function</center></h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1><center>Presenting China Pollution Figures Using Beautiful Soup, Pandas and Matplotlib</center></h1>

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import matplotlib.pyplot as plt

# Fetch URL
html_page = requests.get('https://www.travelchinaguide.com/climate/air-pollution.htm') 
# Obtain the entire HTML page
soup = BeautifulSoup(html_page.content,'html.parser')
# Find all the HTML tables 
tables = soup.find_all(class_="c_tableX")
# Access the second HTML table (i.e. tables[1] instrad of tables[0]) that contains Air Quality information 
# with both table header and table data
table = tables[1] # assign 2nd table in the table list to variable called "table"
table_header = table.find_all('th') # extract table header based on the 'th' tag
# print table header tags and texts
# print(table_header) 
header = []
data = []
for th in table.find_all('th'):
    # print header text
    # print(th.text)
    header.append(th.text)
# print list of headers
# print(header)
all_rows = table.find_all("tr") # extract all the table rows
# Enumerate all the rows to extract needed data
# Obtain both index and values using the enumerate function starting at 2nd row
for i, row in enumerate(all_rows,1):
        if (i < len(all_rows)): # i will start at 0 and stop when i equals the number of rows already processed
            # for each row find all the "td" (i.e. table column) element that holds the data
            tds = all_rows[i].find_all("td") 
             # enumerate each column to extract the "td" value
            for j, td in enumerate(tds,1):
                # print the column name and value
                # print (j,td.text)
                if j==1:
                    rank = td.text
                if j==2:
                    city = td.text
                if j==3:
                    province = td.text
                if j==4:
                    aqi = td.text
                if j==5:
                    air_quality = td.text
                if j==6:
                    pm2_5 = td.text
                if j==7:
                    pm10 = td.text
            # append the all the column values to the data list
            data.append([rank,city,province,aqi,air_quality,pm2_5,pm10])
# Assign row data and column headers to dataframe         
df = pd.DataFrame(data,
  columns = header
)
# Display data frame with both header and data
# df 
# Save dataframe to external csv file
df.to_csv('projects/china_air_quality.csv', sep='\t', encoding='utf-8')
# open csv file and read csv data into Pandas dataframe
df = pd.read_csv("projects/china_air_quality.csv",sep='\t', encoding='utf-8')
df
# Set column headings for entire air quality table and print out the entire table
air_quality_ranking = df[['Rank','City','Province belongs to','AQI','Air Quality Level','PM 2.5','PM 10']]
# air_quality_ranking = pd.DataFrame(df.values[1:], columns=df.values[0])
print("Air Quality Ranking\n")
print(air_quality_ranking)
# Extract cities that are polluted
lightly_polluted    = df[df['Air Quality Level'] == 'Lightly Polluted']
moderately_polluted = df[df['Air Quality Level'] == 'Moderately Polluted']
heavily_polluted    = df[df['Air Quality Level'] == 'Heavely Polluted']
# Combine the cities of different pollution level into one table
selected = lightly_polluted.append(moderately_polluted).append(heavily_polluted)
pc = selected[['Rank','City','AQI','Air Quality Level','PM 2.5','PM 10']]
# ////////////////////////////////////////////////////////////////////
# Display Cities with Pollution
# ////////////////////////////////////////////////////////////////////
print("\nCities with Pollution\n")
print(pc)
cities = pc['City'].tolist()
aqi_lvl = pc['AQI'].tolist()
pm_2_5 = pc['PM 2.5'].tolist()
ax = plt.subplot()
plt.bar(range(len(cities)),aqi_lvl)
# Create ax object here
j = 0
ax_list = []
while j<len(cities):
    ax_list.append(j)
    j += 1
ax.set_xticks(ax_list)
plt.xlabel('Cities')
plt.ylabel('AQI Levels')
plt.title('Cities with High AQI Levels')
ax.set_xticklabels(cities, rotation=70)
plt.show()
# Out:
# Air Quality Ranking
#
#     Rank          City Province belongs to  AQI    Air Quality Level PM 2.5  \
# 0      1         Sanya              Hainan   22            Excellent     10
# 1      2       Lijiang              Yunnan   24            Excellent     12
# 2      3          Dali              Yunnan   24            Excellent     15
# 3      4      Changsha               Hunan   25            Excellent     17
# 4      5        Haikou              Hainan   28            Excellent     15
# 5      6       Qingdao            Shandong   29            Excellent     19
# 6      7       Kunming              Yunnan   33            Excellent     23
# 7      8         Lhasa               Tibet   34            Excellent     15
# 8      9        Dalian           Liaoning    43            Excellent     20
# 9     10     Guangzhou           Guangdong   44            Excellent     30
# 10    11       Guiyang             Guizhou   45            Excellent     31
# ...

# %%
from matplotlib import pyplot as plt
# aqi_lvl = pc['AQI'].tolist()
# pm_2_5 = pc['PM 2.5'].tolist()
ax = plt.subplot()
plt.plot(aqi_lvl, pm_2_5, 'o')
plt.ylabel('PM 2.5')
plt.xlabel('AQI Levels')
plt.show()
